# %%
def greet(name, greeting="Hello"):
    print(f"{name} {greeting}")

# %%
greet(name = "vishesh")
# Out:
# vishesh Hello

# %%
greet("vishesh", "Hi")
# Out:
# vishesh Hi

# %%
# greet(). // error (print(greet(name = "vishesh")))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 greet()
#
# TypeError: greet() missing 1 required positional argument: 'name'

# %% [markdown]
# ### Check for Numpy usecases

# %%
import numpy as np
class perceptron:

    def __init__(self, bias=0):
        self.bias = bias

    def percep(self, weight=[], input=[]):
        self.weight = weight
        return self.learning(X=input, weights=weight)
    
    def update_activation(self, val):
        if(val > 0):
            return 1
        else:
            return 0
    
    def learning(self, X, weights):
        for i in range(X):
            result = result.append(self.weight*i)
        sum = np.sum(result)
        return self.update_activation(sum)


inputs = [10,123,52,5]
weights = [0.1,0.2,0.3,0.4]

p1 = perceptron()
print(p1.percep(weight=weights, input=inputs))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 28
#      25 weights = [0.1,0.2,0.3,0.4]
#      27 p1 = perceptron()
# ---> 28 print(p1.percep(weight=weights, input=inputs))
#
# Cell In[8], line 9, in perceptron.percep(self, weight, input)
#       7 def percep(self, weight=[], input=[]):
#       8     self.weight = weight
# ----> 9     return self.learning(X=input, weights=weight)
#
# Cell In[8], line 18, in perceptron.learning(self, X, weights)
#      17 def learning(self, X, weights):
# ---> 18     for i in range(X):
#      19         result = result.append(self.weight*i)
#      20     sum = np.sum(result)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
import numpy as np
import random

inputs = [1.5,0,2.0]

weights = [0.4, -0.3, -0.8]

bias =0.3

weighted_sum = sum(i*(w*random.randint(1,10)) for i, w in zip(inputs, weights))+bias

output = 1 if weighted_sum >=0 else 0

print(f"Weighted Sum : {weighted_sum:.4f}")

print(f"Output : {output}")



    
        
    
        
def sigmoid(weighted_sum):
    return 1/( 1+ np.exp(-weighted_sum))


print(f"Sigmoid Output : {round(sigmoid(weighted_sum),5)}")
# Out:
# Weighted Sum : 1.9000
# Output : 1
# Sigmoid Output : 0.86989

# %%
# def sigmoid(weighted_sum):
#     return 1/( 1+ np.exp(-weighted_sum))


# print(round(sigmoid(weighted_sum),5))
# Out:
# 0.0163
